# %% [markdown]
# ## 1. Інкапсуляція
# Інкапсуляція означає приховування деталей реалізації об'єкта, забезпечуючи доступ до них лише через спеціальні методи. В Python інкапсуляція реалізується за допомогою:
#
# - Публічних атрибутів і методів (public): доступні звідусіль.
# - Приватних атрибутів і методів (private): позначаються символом _ або __ (наприклад, _attr, __attr).

# %% [markdown]
# ### Завдання №1:
# - Додайте генератор випадкових чисел та викличіть методи deposit та withdraw у циклі передаючи випадкові числа. Виведіть кінцевий результат;

# %%
import random

class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner 
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount
        print(f"Поповнення на: {amount} грн. Поточний баланс: {self.__balance} грн.")

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print(f"Успішне зняття: {amount} грн. Залишок: {self.__balance} грн.")
            return amount
        else:
            print(f"Спроба зняти {amount} грн: Недостатньо коштів!")
            return "Insufficient funds"

    def get_balance(self):
        return self.__balance

account = BankAccount("Bohdan", 1000)
print(f"Початковий баланс власника {account.owner}: {account.get_balance()} грн.\n")

for i in range(1, 6):
    print(f"Транзакція {i}")
    
    random_dep_amount = random.randint(100, 1000)
    account.deposit(random_dep_amount)
    
    random_with_amount = random.randint(100, 1500)
    account.withdraw(random_with_amount)
    print()
print("---")
print(f"Кінцевий результат на рахунку: {account.get_balance()} грн.")
# Out:
# Початковий баланс власника Bohdan: 1000 грн.
#
# Транзакція 1
# Поповнення на: 612 грн. Поточний баланс: 1612 грн.
# Успішне зняття: 1191 грн. Залишок: 421 грн.
#
# Транзакція 2
# Поповнення на: 997 грн. Поточний баланс: 1418 грн.
# Успішне зняття: 1418 грн. Залишок: 0 грн.
#
# Транзакція 3
# Поповнення на: 913 грн. Поточний баланс: 913 грн.
# Спроба зняти 1118 грн: Недостатньо коштів!
#
# Транзакція 4
# Поповнення на: 271 грн. Поточний баланс: 1184 грн.
# Успішне зняття: 259 грн. Залишок: 925 грн.
#
# Транзакція 5
# Поповнення на: 750 грн. Поточний баланс: 1675 грн.
# Успішне зняття: 719 грн. Залишок: 956 грн.
#
# ---
# Кінцевий результат на рахунку: 956 грн.

# %% [markdown]
# ## 2. Наслідування
# - Наслідування дозволяє створювати нові класи на основі існуючих. Новий клас (дочірній) успадковує атрибути та методи базового класу.

# %% [markdown]
# ### Завдання №2:
# - створіть ще один метод у класі Vehicle та викличіть його з обєкта класу Car;

# %%
class Vehicle:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def display_info(self):
        return f"{self.brand} {self.model}"

    # новий метод
    def start_engine(self):
        return f"Двигун автомобіля {self.brand} {self.model} успішно запущено"

class Car(Vehicle):
    def __init__(self, brand, model, seats):
        super().__init__(brand, model)  # виклик конструктора базового класу
        self.seats = seats

    def display_info(self):
        return f"{super().display_info()}, Seats: {self.seats}"


car = Car("Toyota", "Camry", 5)

print(car.display_info())
#викликаю його з обєкта класу Car
print(car.start_engine())
# Out:
# Toyota Camry, Seats: 5
# Двигун автомобіля Toyota Camry успішно запущено

# %% [markdown]
# ## 3. Поліморфізм
# - Поліморфізм означає, що одна і та сама дія може виконуватись по-різному в залежності від об'єкта. Це забезпечується за допомогою перевизначення методів.

# %% [markdown]
# ### Завдання №3:
# - створіть клас Fish у якого небуде метода speak. Як буде поводити себе обєкт класу Fish при виклику методу speak?

# %%
class Animal:
    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

class Fish(Animal):
    pass 

animals = [Dog(), Cat(), Fish()]

for animal in animals:
    # Я додав виведення назви класу (animal.__class__.__name__), 
    # щоб було зрозуміло, чий саме метод викликається
    print(f"{animal.__class__.__name__} каже: {animal.speak()}")
# Out:
# Dog каже: Woof!
# Cat каже: Meow!
# Fish каже: None

# %% [markdown]
# ### Результати виконання:
# - Якщо ми не створимо метод speak у класі Fish, обєкт цього класу просто успадкує метод speak з базового класу Animal.
#
# - Оскільки в класі Animal метод speak містить лише інструкцію pass, виклик цього методу для Fish не викличе помилки, але поверне спеціальне значення None

# %% [markdown]
# ## 4. Абстракція
# - Абстракція приховує складність та залишає лише необхідні деталі. В Python це реалізується через абстрактні класи (використовуючи модуль abc).

# %% [markdown]
# тут не було завдання :(

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

circle = Circle(5)
print(circle.area())
# Out:
# 78.5

# %% [markdown]
# ## 5. Використання парадигм для створення простої гри

# %% [markdown]
# ### Завдання №4:
# Додайте третій тип зброї — Bow (лук), який:
#
# - має власний параметр range_power (дальність);
# - метод attack() з формулою шкоди attack_power + randint(5, 15) + range_power;
# - має метод reload(), який збільшує дальність (range_power += 1); Додайте випадковий вибір зброї з трьох можливих (Sword, Axe, Bow); Зробіть гру покроковою, де користувач може робити хід та вибирати дії з своїм типом зброї (наприклад, атакувати або накласти підсилення щоб підвищити ефективність зброї на наступному кроці);

# %%
from abc import ABC, abstractmethod
from random import randint, choice

class Item(ABC):
    def __init__(self, name:str, health = 500):
        self.name = name
        self.health = health
    
    @abstractmethod
    def attack(self, another_item):
        pass

class Sword(Item):
    def __init__(self, name, attack_power:int):
        super().__init__(name=name)
        self.__attack_power = attack_power
        self._sharp = 0
    
    def attack(self, another_item:Item):
        current_attack = self.__attack_power + self._sharp + randint(0, 10)
        another_item.health -= current_attack
        return f"Завдаємо удару мечем {self.name} та наносимо {current_attack} шкоди. У {another_item.name} залишалось здоровя: {another_item.health}"
    
    @property
    def get_attack_power(self):
        return f"Атака меча {self.name}: {self.__attack_power + self._sharp} одиниць"
    
    def sharpening(self):
        self._sharp += 1

class Axe(Item):
    def __init__(self, name, attack_power:int):
        super().__init__(name=name)
        self.__attack_power = attack_power
        self._sharp = 0
    
    def attack(self, another_item:Item):
        current_attack = self.__attack_power + randint(0, 20)
        another_item.health -= current_attack
        return f"Завдаємо удару сокирою {self.name} та наносимо {current_attack} шкоди. У {another_item.name} залишалось здоровя: {another_item.health}"

    @property
    def get_attack_power(self):
        return f"Атака сокири {self.name}: {self.__attack_power + self._sharp} одиниць"

class Bow(Item):
    def __init__(self, name, attack_power:int):
        super().__init__(name=name)
        self.__attack_power = attack_power
        self.range_power = 0
        
    def attack(self, another_item:Item):
        current_attack = self.__attack_power + randint(5, 15) + self.range_power
        another_item.health -= current_attack
        return f"Стріляємо з лука {self.name} та наносимо {current_attack} шкоди. У {another_item.name} залишалось здоровя: {another_item.health}"
        
    def reload(self):
        self.range_power += 1

# Випадковий вибір зброї
weapons = [
    Sword("Ескалібур", 100), 
    Axe("Кратос", 95), 
    Bow("Леголас", 90)
]

player = choice(weapons)
enemy = choice(weapons)

print(f"Ваша зброя: {player.__class__.__name__}")
print(f"Зброя супротивника: {enemy.__class__.__name__}")

# Покрокова гра
while player.health > 0 and enemy.health > 0:
    action = input("\nВаш хід (1 - атака, 2 - підсилення): ")
    
    if action == "1":
        print(player.attack(enemy))
    elif action == "2":
        if isinstance(player, Sword):
            player.sharpening()
            print("Ви нагострили меч!")
        elif isinstance(player, Bow):
            player.reload()
            print("Ви збільшили дальність лука!")
        elif isinstance(player, Axe):
            print("Сокира не має підсилення, хід витрачено!")
            
    if enemy.health <= 0:
        print("\nВи перемогли!")
        break
        
    # Хід супротивника
    print("\nХід супротивника:")
    if randint(1, 2) == 1:
        print(enemy.attack(player))
    else:
        if isinstance(enemy, Sword):
            enemy.sharpening()
            print("Супротивник нагострив меч!")
        elif isinstance(enemy, Bow):
            enemy.reload()
            print("Супротивник збільшив дальність лука!")
        elif isinstance(enemy, Axe):
            print(enemy.attack(player)) # Якщо це сокира, бот просто атакує
            
    if player.health <= 0:
        print("\nВи програли!")
        break
# Out:
# Ваша зброя: Bow
# Зброя супротивника: Bow
# Ви збільшили дальність лука!
#
# Хід супротивника:
# Стріляємо з лука Леголас та наносимо 103 шкоди. У Леголас залишалось здоровя: 397
# Ви збільшили дальність лука!
#
# Хід супротивника:
# Супротивник збільшив дальність лука!
# Ви збільшили дальність лука!
#
# Хід супротивника:
# Стріляємо з лука Леголас та наносимо 109 шкоди. У Леголас залишалось здоровя: 288
# Стріляємо з лука Леголас та наносимо 101 шкоди. У Леголас залишалось здоровя: 187
#
# Хід супротивника:
# Стріляємо з лука Леголас та наносимо 99 шкоди. У Леголас залишалось здоровя: 88
# Стріляємо з лука Леголас та наносимо 108 шкоди. У Леголас залишалось здоровя: -20
#
# Ви перемогли!
