# %%
from datetime import datetime
name = "Orest"
location = "Lviv"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Orest start programming at 2025-09-11 17:57:11.073679. Lviv is the best city!

# %% [markdown]
# # Моя перша програма на Python: виведення імені, дати та міста
